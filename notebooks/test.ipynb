# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
models = {
            "Random Forest": RandomForestClassifier(verbose=1),
            "Decision Tree": DecisionTreeClassifier(),
            "Gradient Boosting": GradientBoostingClassifier(verbose=1),
            "Logistic Regression": LogisticRegression(verbose=1),
            "AdaBoost": AdaBoostClassifier()
        }

# %%
params={
            "Decision Tree": {
                'criterion': ['gini','entrophy','log_loss'],
            },
            "Random Forest": {
                'n_estimators':[8,16,32,64,128,256]
            },
            "Gradient Boosting": {
                'learning_rate':[.1,.01,.05,.001],
                'subsample':[0.6,0.7,0.75,0.8,0.85,0.9],
                'n_estimators':[8,16,32,64,128,256]
            },
            "Logistic Regression":{},
            "AdaBoost":{
                'learing_rate':[.1,.01,0.5,.001],
                'n_estimators':[8,16,32,64,128,256]
            }

        }

# %%
l = list(models)
print(l)
# Out:
# ['Random Forest', 'Decision Tree', 'Gradient Boosting', 'Logistic Regression', 'AdaBoost']

# %%
models.keys()
# Out:
# dict_keys(['Random Forest', 'Decision Tree', 'Gradient Boosting', 'Logistic Regression', 'AdaBoost'])

# %%
list(models.keys())
# Out:
# ['Random Forest',
#  'Decision Tree',
#  'Gradient Boosting',
#  'Logistic Regression',
#  'AdaBoost']

# %%
list(models.keys())[2]
# Out:
# 'Gradient Boosting'

# %%
models.values()
# Out:
# dict_values([RandomForestClassifier(verbose=1), DecisionTreeClassifier(), GradientBoostingClassifier(verbose=1), LogisticRegression(verbose=1), AdaBoostClassifier()])

# %%
list(models.values())
# Out:
# [RandomForestClassifier(verbose=1),
#  DecisionTreeClassifier(),
#  GradientBoostingClassifier(verbose=1),
#  LogisticRegression(verbose=1),
#  AdaBoostClassifier()]

# %%
len(l)
# Out:
# 5

# %%
range(len(l))
# Out:
# range(0, 5)

# %%
for i in range(len(l)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(len(l)):
    model = list(models.values())[i]
    para = params[list(models.keys())[i]]
    print(model)
    print(para)
# Out:
# RandomForestClassifier(verbose=1)
# {'n_estimators': [8, 16, 32, 64, 128, 256]}
# DecisionTreeClassifier()
# {'criterion': ['gini', 'entrophy', 'log_loss']}
# GradientBoostingClassifier(verbose=1)
# {'learning_rate': [0.1, 0.01, 0.05, 0.001], 'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9], 'n_estimators': [8, 16, 32, 64, 128, 256]}
# LogisticRegression(verbose=1)
# {}
# AdaBoostClassifier()
# {'learing_rate': [0.1, 0.01, 0.5, 0.001], 'n_estimators': [8, 16, 32, 64, 128, 256]}

# %%
model_report = {"Logistic":0.45,
"Gradient":0.55,
"Decision":0.76,
"AdaBoost":0.78
}

# %%
list(model_report.values()).index(0.78)
# Out:
# 3

# %%
[list(model_report.values()).index(0.78)]
# Out:
# [3]
